# %% [markdown]
# ![Screen%20Shot%202022-06-30%20at%2011.02.38.png](attachment:Screen%20Shot%202022-06-30%20at%2011.02.38.png)

# %%
# exaple for entry 3
x_input = [0.7, 0.4, 0.2]
w_weights = [0.4, 0.2, 0.6]
threshold = 0.5

def step(weighted_sum):
    if weighted_sum > threshold:
        return 1
    else:
        return 0

def perceptron():
    weighted_sum = 0
    for x,w in zip(x_input, w_weights):
        weighted_sum += x * w
        print(weighted_sum)
    return step(weighted_sum)

output = perceptron()
print("output: " + str(output))
# Out:
# 0.27999999999999997
# 0.36
# 0.48
# output: 0

# %% [markdown]
# ![Screen%20Shot%202022-06-30%20at%2011.04.49.png](attachment:Screen%20Shot%202022-06-30%20at%2011.04.49.png)

# %% [markdown]
# # Cross Entropy Loss

# %% [markdown]
# ![Screen%20Shot%202022-06-30%20at%2011.08.03.png](attachment:Screen%20Shot%202022-06-30%20at%2011.08.03.png)

# %%
import math

input_data = [(0.26, 1),  # 0.26 -calculated weighted_sum,  1 - target
              (0.20, 0),
              (0.48, 1),
              (0.30, 0)]

def cross_entropy(input_data):
    loss = 0
    n = len(input_data)
    for entry in input_data:
        w_sum = entry[0]
        y = entry[1]
        loss += -(y*math.log10(w_sum) + (1-y)*math.log10(1-w_sum))
        print(-(y*math.log10(w_sum) + (1-y)*math.log10(1-w_sum)))   # aby spr dla kadego składnika
    return loss/n

error_term = cross_entropy(input_data)
print("cross entropy loss is: ",  error_term)
# Out:
# 0.585026652029182
# 0.09691001300805639
# 0.3187587626244128
# 0.1549019599857432
# cross entropy loss is:  0.2888993469118486

# %% [markdown]
# ![Screen%20Shot%202022-06-30%20at%2011.07.11.png](attachment:Screen%20Shot%202022-06-30%20at%2011.07.11.png)
